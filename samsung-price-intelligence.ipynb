# %% [markdown]
# <a href="https://www.kaggle.com/code/sahilkhan08/samsung-price-intelligence?scriptVersionId=318581214" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Samsung Price Intelligence — Analysis Notebook Code

# ==============================
# 1. IMPORT LIBRARIES
# ==============================
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Plot style
sns.set_theme(style="whitegrid")

# %%
# ==============================
# 2. LOAD DATA
# ==============================
file_path = "/kaggle/input/datasets/sahilkhan08/samsung-features/samsung_features.csv"
df = pd.read_csv(file_path)

print("Dataset Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
print("\nPreview:")
print(df.head())
# Out:
# Dataset Shape: (154, 18)
#
# Columns:
# ['name', 'url', 'brand', 'platform', 'image', 'title_raw', 'scraped_at', 'release_month', 'release_year', 'display_raw', 'chipset_raw', 'battery_raw', 'storage_raw', 'ram_raw', 'series', 'device_age', 'battery_category', 'performance_score']
#
# Preview:
#                name                                                url  \
# 0       Galaxy F70e  https://www.gsmarena.com/samsung_galaxy_f70e_5...
# 1        Galaxy A07  https://www.gsmarena.com/samsung_galaxy_a07_5g...
# 2  Galaxy Z TriFold  https://www.gsmarena.com/samsung_galaxy_z_trif...
# 3        Galaxy M17  https://www.gsmarena.com/samsung_galaxy_m17_5g...
# 4        Galaxy F07  https://www.gsmarena.com/samsung_galaxy_f07-14...
#
#      brand  platform                                              image  \
# 0  Samsung  GSMArena  https://fdn2.gsmarena.com/vv/bigpic/samsung-ga...
# 1  Samsung  GSMArena  https://fdn2.gsmarena.com/vv/bigpic/samsung-ga...
# 2  Samsung  GSMArena  https://fdn2.gsmarena.com/vv/bigpic/samsung-ga...
# 3  Samsung  GSMArena  https://fdn2.gsmarena.com/vv/bigpic/samsung-ga...
# 4  Samsung  GSMArena  https://fdn2.gsmarena.com/vv/bigpic/samsung-ga...
#
#                                            title_raw  \
# 0  Samsung Galaxy F70e 5G Android smartphone. Ann...
# 1  Samsung Galaxy A07 5G Android smartphone. Anno...
# 2  Samsung Galaxy Z TriFold 5G Android smartphone...
# 3  Samsung Galaxy M17 5G Android smartphone. Anno...
# 4  Samsung Galaxy F07 Android smartphone. Announc...
#
#                          scraped_at release_month  release_year  display_raw  \
# 0  2026-02-18T17:46:18.673885+00:00           Feb          2026          6.7
# 1  2026-02-18T17:46:18.673932+00:00           Jan          2026          6.7
# 2  2026-02-18T17:46:18.673967+00:00           Dec          2025         10.0
# 3  2026-02-18T17:46:18.674002+00:00           Oct          2025          6.7
# 4  2026-02-18T17:46:18.674035+00:00           Oct          2025          6.7
#
#           chipset_raw  battery_raw  storage_raw  ram_raw series  device_age  \
# 0      Dimensity 6300         6000          128        6      F           0
# 1      Dimensity 6300         6000          128        6      A           0
# 2  Snapdragon 8 Elite         5600         1024       16      Z           1
# 3         Exynos 1330         5000          128        8      M           1
# 4           Helio G99         5000           64        4      F           1
#
#   battery_category  performance_score
# 0             High               19.7
# 1             High               19.7
# 2             High               50.0
# 3           Medium               23.7
# 4           Medium               15.2

# %%
# ==============================
# 3. DATA QUALITY CHECK
# ==============================
print("\nMissing Values:")
print(df.isna().sum())

print("\nData Types:")
print(df.dtypes)

print("\nBasic Statistics:")
print(df.describe())
# Out:
# Missing Values:
# name                 0
# url                  0
# brand                0
# platform             0
# image                0
# title_raw            0
# scraped_at           0
# release_month        0
# release_year         0
# display_raw          0
# chipset_raw          0
# battery_raw          0
# storage_raw          0
# ram_raw              0
# series               0
# device_age           0
# battery_category     0
# performance_score    0
# dtype: int64
#
# Data Types:
# name                  object
# url                   object
# brand                 object
# platform              object
# image                 object
# title_raw             object
# scraped_at            object
# release_month         object
# release_year           int64
# display_raw          float64
# chipset_raw           object
# battery_raw            int64
# storage_raw            int64
# ram_raw                int64
# series                object
# device_age             int64
# battery_category      object
# performance_score    float64
# dtype: object
#
# Basic Statistics:
#        release_year  display_raw  battery_raw  storage_raw     ram_raw  \
# count    154.000000   154.000000   154.000000   154.000000  154.000000
# mean    2022.610390     6.667013  5012.987013   263.064935    7.889610
# std        1.693168     0.385838   610.871155   230.152569    2.818152
# min     2020.000000     6.100000  3300.000000    32.000000    2.000000
# 25%     2021.000000     6.500000  4900.000000   128.000000    6.000000
# 50%     2022.000000     6.600000  5000.000000   256.000000    8.000000
# 75%     2024.000000     6.700000  5000.000000   256.000000    8.000000
# max     2026.000000    10.000000  7000.000000  1024.000000   16.000000
#
#        device_age  performance_score
# count  154.000000         154.000000
# mean     3.389610          24.501429
# std      1.693168           7.335159
# min      0.000000          10.750000
# 25%      2.000000          19.600000
# 50%      4.000000          24.150000
# 75%      5.000000          24.700000
# max      6.000000          50.000000

# %%
# ==============================
# 4. TREND ANALYSIS OVER TIME
# ==============================

# --- RAM Trend ---
ram_trend = df.groupby("release_year")["ram_raw"].mean()

plt.figure()
ram_trend.plot(marker="o")
plt.title("Average RAM Trend Over Years")
plt.xlabel("Release Year")
plt.ylabel("Average RAM (GB)")
plt.tight_layout()
plt.show()

# --- Battery Trend ---
battery_trend = df.groupby("release_year")["battery_raw"].mean()

plt.figure()
battery_trend.plot(marker="o")
plt.title("Average Battery Capacity Trend Over Years")
plt.xlabel("Release Year")
plt.ylabel("Average Battery (mAh)")
plt.tight_layout()
plt.show()

# --- Display Size Trend ---
display_trend = df.groupby("release_year")["display_raw"].mean()

plt.figure()
display_trend.plot(marker="o")
plt.title("Average Display Size Trend Over Years")
plt.xlabel("Release Year")
plt.ylabel("Average Display Size (inches)")
plt.tight_layout()
plt.show()

# %%
# ==============================
# 5. GALAXY SERIES COMPARISON
# ==============================
series_stats = df.groupby("series")[["ram_raw", "battery_raw", "performance_score"]].mean()

# --- RAM by Series ---
plt.figure()
series_stats["ram_raw"].plot(kind="bar")
plt.title("Average RAM by Galaxy Series")
plt.xlabel("Series")
plt.ylabel("RAM (GB)")
plt.tight_layout()
plt.show()

# --- Battery by Series ---
plt.figure()
series_stats["battery_raw"].plot(kind="bar")
plt.title("Average Battery by Galaxy Series")
plt.xlabel("Series")
plt.ylabel("Battery (mAh)")
plt.tight_layout()
plt.show()

# --- Performance Score by Series ---
plt.figure()
series_stats["performance_score"].plot(kind="bar")
plt.title("Performance Score by Galaxy Series")
plt.xlabel("Series")
plt.ylabel("Performance Score")
plt.tight_layout()
plt.show()

# %%
# ==============================
# 6. CORRELATION HEATMAP
# ==============================
numeric_cols = [
    "ram_raw",
    "storage_raw",
    "battery_raw",
    "display_raw",
    "performance_score",
    "device_age",
]

corr_matrix = df[numeric_cols].corr()

plt.figure()
sns.heatmap(corr_matrix, annot=True, fmt=".2f")
plt.title("Correlation Heatmap of Key Features")
plt.tight_layout()
plt.show()

# %%
# ==============================
# 7. RELEASE CYCLE INSIGHTS
# ==============================
releases_per_year = df["release_year"].value_counts().sort_index()

plt.figure()
releases_per_year.plot(kind="bar")
plt.title("Number of Samsung Phones Released Per Year")
plt.xlabel("Year")
plt.ylabel("Number of Devices")
plt.tight_layout()
plt.show()

series_distribution = df["series"].value_counts()

plt.figure()
series_distribution.plot(kind="bar")
plt.title("Distribution of Galaxy Series in Dataset")
plt.xlabel("Series")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# # ==============================
# # 8. KEY FINDINGS SUMMARY
# # ==============================
# print("\n===== KEY INSIGHTS =====")
# print("- RAM capacity shows a steady increase across release years.")
# print("- Battery capacity stabilizes around the 5000 mAh range for most devices.")
# print("- Mid-range series dominate total device launches.")
# print("- Foldable (Z series) devices show high performance but lower release frequency.")

# %% [markdown]
# # ==============================
# # 9. FUTURE WORK
# # ==============================
# print("\n===== FUTURE WORK =====")
# print("- Integrate smartphone price data for price-performance analysis.")
# print("- Build machine learning models to predict performance tier or price.")
# print("- Compare Samsung trends with other smartphone brands.")
#
# print("\nAnalysis complete.")
